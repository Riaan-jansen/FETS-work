# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
dict1 = {
        'proton'    : 4.28E-3,
        # 'deuteron'  : 2.16E-6,
        # 'tritium'   : 1.03E-7,
        # 'alpha'     : 2.81E-4,
        # 'helium-3'  : 3.67E-5,
        # # 'lithium-7' : 2.94E-8,
        # # ignoring li-7 and li-6
        # 'beryllium-7': 2.91E-4,
        # 'boron-10'  : 1.18E-7
        'other'     : 6.11E-4
        }

dict2 = {
        # 'proton'    : 4.28E-3,
        # 'deuteron'  : 2.16E-6,
        # 'tritium'   : 1.03E-7,
        'helium-4'     : 2.81E-4 ,
        'helium-3'  : 3.67E-5 ,
        # 'lithium-7' : 2.94E-8,
        # ignoring li-7 and li-6
        'beryllium-7': 2.91E-4,
        # 'boron-10'  : 1.18E-7
        'other'      : 2.3E-6
        }

# %%
# https://matplotlib.org/stable/gallery/pie_and_polar_charts/bar_of_pie.html
from matplotlib.patches import ConnectionPatch

fig, (ax1, ax2) = plt.subplots(1,2, figsize=(9,5))
fig.subplots_adjust(wspace=0)

# pie chart parameters
overall_ratios = [ele for ele in dict2.values()]
labels = dict2.keys()
explode = [0.05, 0.05, 0.05, 0.05]
# rotate so that first wedge is split by the x-axis
angle = -180 * overall_ratios[0]
colours = ['green', 'red', 'orange', 'C0']
shadow={'ox': -0.04, 'edgecolor': 'none', 'shade': 0.9}

wedges, *_ = ax1.pie(overall_ratios, autopct='%1.1f%%', startangle=angle,
                     labels=labels, colors=colours, explode=explode)

# bar chart parameters
other_lis = ['boron-10', 'triton', 'deuteron']
# other_tab = [1.18E-7 / (4.893e-3 - 4.28E-3)   ,  1.03E-7 / (4.893e-3 - 4.28E-3) ,
#              2.16E-6 / (4.893e-3 - 4.28E-3) ]
other_tab = [1.18E-7, 1.03E-7, 2.16E-6 ]
heights = [0.1, 0.1, 0.8]

bottom = 1
width = .2

# Adding from the top matches the legend.
for j, label in enumerate(other_lis):
    bottom -= heights[j]
    bc = ax2.bar(0, heights[j] + 0.000004*j, width, bottom=bottom, color='C0', label=label,
                 alpha=0.2 + 0.35 * j)
    ax2.bar_label(bc, labels=[f"{other_tab[j]*100/6.11e-4:.4f}%"], label_type='center')



ax2.set_title('"Other" Decay Products')
ax2.legend()
ax2.axis('off')
ax2.set_xlim(- 2.5 * width, 2.5 * width)

plt.suptitle('Decay Products in Lithium Target from Proton Irradiation')
plt.show()

# %%
base_dict = {
        ''
}
